# %% [markdown]
# <a href="https://colab.research.google.com/github/Seba1905lobos/sebastianlobos_PGY1121_006V_D/blob/main/Untitled31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ganancias_a = 0
ganancias_b = 0
ganancias_c = 0
ganancias_d = 0
total_a = 0
total = 0
rut = 0
tablero = [["[ ]" for _ in range(4)] for _ in range(10)]
coordenadas_X = []

def mostrar_tablero():
    print("  A   B   C   D")
    for i in range(len(tablero)):
        print(str(i) + " ".join(tablero[i]))

def actualizar_coordenada(fila, columna):

   tablero[fila][columna] = "[X]"
   coordenadas_X.append((fila, columna))

def obtener_rut():
  global  rut
  rut = input("Ingresa tu RUT: ")
  while not rut.isdigit() or len(rut) != 9:
        print("El RUT es inválido. Debe contener solo números y tener una longitud de 9 caracteres.")
        rut = input("Ingresa tu RUT: ")
def ganancias():
    if columna == 0:
      ganancias_a = 3800
    if columna == 1:
      ganancias_b = 3000
    if columna == 2:
      ganancias_c =  2800
    if columna == 2:
      ganancias_d =  3500
    total = ganancias_a + ganancias_b + ganancias_c + ganancias_d


while True:
  try:
    print("__________MENU__________")
    print("[1] Comprar departamento ")
    print("[2] Mostrar departamentos disponibles ")
    print("[3] Ver listado de compradores ")
    print("[4] Mostrar ganancias totales ")
    print("[5] Salir")
    menu = int(input("escoja una opcion: "))

    if menu == 1:
       print("")
       obtener_rut()
       coordenada = input("Ingrese la coordenada (fila(0-9)↓, columna(o-3)➜: ")

       fila = int(coordenada[0])
       columna = int(coordenada[2])

       if fila < 0 or fila > 9 or columna < 0 or columna > 3:
        print("Coordenada fuera de rango. Intente nuevamente.")
        continue

       if (fila, columna) in coordenadas_X:
         ("Esa coordenada ya está ocupada. Intente nuevamente.")

       actualizar_coordenada(fila, columna)
       print("Coordenada actualizada con éxito.")
       mostrar_tablero()
       if columna == 0:
                ganancias_a = 3800
       if columna == 1:
             ganancias_b = 3000
       if columna == 2:
             ganancias_c =  2800
       if columna == 2:
             ganancias_d =  3500
       total = ganancias_a + ganancias_b + ganancias_c + ganancias_d


    elif menu == 2:
        print("")
        mostrar_tablero()
    elif menu == 3:
         print("")
         print("RUN:")
         if rut == 0:
          print ("todavia no se a ingresado ningun rut")
         else:
          print(rut)
    elif menu == 4:
          print("")
          print(f"Tipo A: ",ganancias_a,"UF")
          print(f"Tipo B: ",ganancias_b,"UF")
          print(f"Tipo C: ",ganancias_c,"UF")
          print(f"Tipo D: ",ganancias_d,"UF")
          print(f"total: ",total,"UF")

    elif menu == 5:
            print("")
            print("que tenga un buen dia")
    elif menu >  5 or menu < 0:
              print("")
              print("intente con otro numero")
  except ValueError:
    print("")
    print("opcion no valida")
